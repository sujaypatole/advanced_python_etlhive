# %% [markdown]
# ### Polymorphism in Functions

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
a="Raman"
type(a)
# Out:
# str

# %%
len(a)
# Out:
# 5

# %%
b = [1,2,3,4,5,6,11]
type(b)
# Out:
# list

# %%
len(b)
# Out:
# 7

# %%
c = ("a","b",True)
type(c)
# Out:
# tuple

# %%
len(c)
# Out:
# 3

# %%
marks = {
   "Rahul":78,
   "Raman":83,
   "Priya":94,
   "Suresh":81
}

# %%
len(marks)
# Out:
# 4

# %%
students = {
   "roll_no":[1,2,3],
   "name":["John","Jane","Raman"]
}

type(students)
# Out:
# dict

# %%
import pandas as pd
df = pd.DataFrame(students)
df
# Out:
#    roll_no   name
# 0        1   John
# 1        2   Jane
# 2        3  Raman

# %%
len(df) # Return number of rows
# Out:
# 3

# %% [markdown]
# ### Polymorphism in Operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
12 + 13
# Out:
# 25

# %%
2.5 + 4.7
# Out:
# 7.2

# %%
"Example" + "Random" # String concatination
# Out:
# 'ExampleRandom'

# %%
a = [3, 4, 5]
b = [8, 9, 10]
a+b # List concatenation and merge two lists into single list
# Out:
# [3, 4, 5, 8, 9, 10]

# %%
b + a # Order of list matters
# Out:
# [8, 9, 10, 3, 4, 5]

# %%
a*3
# Out:
# [3, 4, 5, 3, 4, 5, 3, 4, 5]

# %%
d = "example"
d*4 # which is equal to d + d + d + d
# Out:
# 'exampleexampleexampleexample'

# %% [markdown]
# ### Polymorphism in classes

# %%
class India:

   def capital(self):
      print("New Delhi is capital of India")

   def language(self):
      print("Hindi is widely sopken language")

# %%
class USA:

   def capital(self):
      print("Washington D.C. is capital of USA")

   def language(self):
      print("English is widely spoken is USA")

# %%
class France:

   def capital(self):
      print("Paris is capital of France")
   
   def language(self):
      print("French is widely spoken in France")

# %%
c1 = India()
c2 = USA()
c3 = France()

# %%
type(c1)
# Out:
# __main__.India

# %%
type(c2)
# Out:
# __main__.USA

# %%
type(c3)
# Out:
# __main__.France

# %%
c1.capital()
# Out:
# New Delhi is capital of India

# %%
c1.language()
# Out:
# Hindi is widely sopken language

# %%
c2.capital()
# Out:
# Washington D.C. is capital of USA

# %%
c2.language()
# Out:
# English is widely spoken is USA

# %%
c3.capital()
# Out:
# Paris is capital of France

# %%
c3.language()
# Out:
# French is widely spoken in France

# %%
for i in (c1, c2, c3):
   print(type(i))
   i.capital()
   i.language()
   print("\n===========================\n")
# Out:
# <class '__main__.India'>
# New Delhi is capital of India
# Hindi is widely sopken language
#
# ===========================
#
# <class '__main__.USA'>
# Washington D.C. is capital of USA
# English is widely spoken is USA
#
# ===========================
#
# <class '__main__.France'>
# Paris is capital of France
# French is widely spoken in France
#
# ===========================

# %% [markdown]
# ### Polymorphisim in calculating area and perimeter of different shapes

# %%
class Rectangle:
   def __init__(self, width, height):
      self.width = width
      self.height = height

   def perimeter(self):
      return 2 * (self.width + self.height)
   
   def area(self):
      return self.width * self.height

# %%
from math import pi
pi
# Out:
# 3.141592653589793

# %%
class Circle:
   def __init__(self,radius):
      self.radius = radius

   def perimeter(self):
      return 2*pi*self.radius
   
   def area(self):
      return pi * (self.radius**2)

# %%
s1 = Rectangle(10,12)
s2 = Circle(12)
s3 = Rectangle(3, 6)
s4 = Rectangle(3,3)

# %%
shape_ = (s1, s2, s3, s4)

for i in shape_:
   print(f"Perimeter: {i.perimeter():.2f}")
   print(f"Area: {i.area():.2f}")
   print("\n================================\n")
# Out:
# Perimeter: 44.00
# Area: 120.00
#
# ================================
#
# Perimeter: 75.40
# Area: 452.39
#
# ================================
#
# Perimeter: 18.00
# Area: 18.00
#
# ================================
#
# Perimeter: 12.00
# Area: 9.00
#
# ================================

# %%
import builtins
dir(builtins) #List of builtin class names
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
#  'ReferenceError',
#  'ResourceWarning',
#  'RuntimeError',
#  'RuntimeWarning',
#  'StopAsyncIteration',
#  'StopIteration',
#  'SyntaxError',
#  'SyntaxWarning',
#  'SystemError',
#  'SystemExit',
#  'TabError',
#  'TimeoutError',
#  'True',
#  'TypeError',
#  'UnboundLocalError',
#  'UnicodeDecodeError',
#  'UnicodeEncodeError',
#  'UnicodeError',
#  'UnicodeTranslateError',
#  'UnicodeWarning',
#  'UserWarning',
#  'ValueError',
#  'Warning',
#  'WindowsError',
#  'ZeroDivisionError',
#  '__IPYTHON__',
#  '__build_class__',
#  '__debug__',
#  '__doc__',
#  '__import__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'abs',
#  'aiter',
#  'all',
#  'anext',
#  'any',
#  'ascii',
#  'bin',
#  'bool',
#  'breakpoint',
#  'bytearray',
#  'bytes',
#  'callable',
#  'chr',
#  'classmethod',
#  'compile',
#  'complex',
#  'copyright',
#  'credits',
#  'delattr',
#  'dict',
#  'dir',
#  'display',
#  'divmod',
#  'enumerate',
#  'eval',
#  'exec',
#  'execfile',
#  'filter',
#  'float',
#  'format',
#  'frozenset',
#  'get_ipython',
#  'getattr',
#  'globals',
#  'hasattr',
#  'hash',
#  'help',
#  'hex',
#  'id',
#  'input',
#  'int',
#  'isinstance',
#  'issubclass',
#  'iter',
#  'len',
#  'license',
#  'list',
#  'locals',
#  'map',
#  'max',
#  'memoryview',
#  'min',
#  'next',
#  'object',
#  'oct',
#  'open',
#  'ord',
#  'pow',
#  'print',
#  'property',
#  'range',
#  'repr',
#  'reversed',
#  'round',
#  'runfile',
#  'set',
#  'setattr',
#  'slice',
#  'sorted',
#  'staticmethod',
#  'str',
#  'sum',
#  'super',
#  'tuple',
#  'type',
#  'vars',
#  'zip']

# %%
import keyword
keyword.kwlist # Generates the list of builtin keywords
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# ##### Names from above built-ins classes and keywords are not supposed to be used in usual programming practice
